# %% [markdown]
# # Introduction to Data Science 2025
#
# # Bonus exercises

# %% [markdown]
# ## Exercise 1: EDA of unemployed highly educated people in Finland
#
# In this assignment, you will explore time series data on unemployment of highly educated people in Finland combined with two datasets of your own choosing. The idea of the assignment is to look into how the unemployed highly educated population varies over time and across different areas by using the data wrangling, exploratory data analysis, and visualization tools discussed during the course.
#
# First, please download the Statistics Finland's CSV dataset (available in the course MOOC Materials) that contains data on employment and unemployment numbers grouped by level of education, province, and year.
#
# Read in the data to a data frame, and have a look at the rows and columns it contains. For ease of use, you can set the year column as the index. Perform any other preprocessing you see fit. If you are working in Python, you can do this using the pandas library.
#
# **Hint**: you can also create new useful columns using the existing ones.

# %%
import pandas as pd

# %%
unemployment_df = pd.read_csv("unemployment_data.csv")
finance_df = pd.read_excel("PKS_kuntien_talouden_tunnusluvut.xls", skiprows=2, nrows=34)
finance_df = finance_df.iloc[:, :-1].rename(columns={finance_df.columns[0]: "Indicator"})

finance_df.tail()
# Out:
#                                   Indicator        1998        1999  \
# 29         Konsernin omavaraisuus 31.12., %   44.572845   46.163446
# 30        Rahoitusvarallisuus 31.12., €/as.  274.238767  132.957826
# 31  Suhteellinen velkaantuneisuus 31.12., %   28.482588   26.595847
# 32            Kertynyt yli-/alijäämä, €/as.  284.922047  472.295384
# 33  Konsernin kertynyt yli-/alijäämä, €/as. -199.876033  -24.363191
#
#           2000        2001        2002        2003         2004         2005  \
# 29   66.434038   66.257816   62.312796   61.758118    61.708717    62.280323
# 30  401.583744  207.143597 -400.174374 -562.952103  -747.146031  -889.319938
# 31   20.340731   23.221700   36.889021   37.271959    39.632533    38.286789
# 32  737.717977  795.096817  520.065533  701.805732  1049.081829  1330.064806
# 33  196.080876  127.830132 -159.895376  -35.410223   320.401183   562.524848
#
#            2006         2007         2008         2009
# 29    62.510523    62.800610    62.792677    60.483877
# 30  -541.758411  -607.479627  -804.601402 -1207.513500
# 31    34.149265    35.327052    33.404449    39.129671
# 32  1845.681560  2285.840174  2770.091757  2765.869547
# 33  1212.082456  1775.389557  2292.785486  2342.795920

# %% [markdown]
# Next, find two time series datasets of your choice to combine with the unemployment data. These can be time series data on factors that you are interested in that might be connected to unemployment, and should cover at least some of the same years as the unemployment data. Please find the datasets from some source other than Statistics Finland (Tilastokeskus).
#
# Read in your datasets, perform any necessary cleaning (such as handling missing values or removing unnecessary columns, et cetera). Preprocess the data so that the features are presented on a yearly level. Then, combine the preprocessed datasets to the unemployment data using the year column to link the datasets.

# %%
## Use this cell for your code

# %% [markdown]
# Perform exploratory data analysis on your merged dataset. You can use methods of your choice to compute useful statistics on the data, and to visualize different features and the interactions between them. Focus on the question of whether high education level (Master's level) and other factors in your merged dataset are associated with unemployment.

# %%
## Use this cell for your code

# %% [markdown]
# Create a geographical or other type of plot showcasing the trends in the unemployment of highly educated people across different provinces over time. Compare the provinces based on your plot.

# %%
## Use this cell for your code

# %% [markdown]
# Reflect briefly on your findings. For example, which features seemed interesting with respect to changes in unemployment among the highly educated population? How do different provinces compare? What should be done to ensure that the number of unemployed highly educated people can be compared fairly across years and provinces?
#
# **Hint**: should we look at the raw numbers or maybe consider them relative to something else?

# %% [markdown]
# ## Exercise 2: AI Act
#
# In this exercise, we ask you to think about the different AI services you come accross in your daily life and consider them in terms of the AI Act's risk pyramid.
#
# 1. Brainstorm & List: For 48 hours, keep a log of every application, software, or service you interact with that you suspect uses AI. Think about social media feeds, recommendation engines (Netflix, Spotify, Amazon), grammar checkers, spam filters, navigation apps, and virtual assistants. We'd expect that most of you will be able to identify at least 10 examples.
#
# 2. Select & Analyze: Choose three distinct AI systems from your list. For each one, research and describe its primary function and how AI is used to achieve it.
#
# 3. Classify the Risk: Using the AI Act's risk pyramid as a guide, classify each of your three chosen AI systems into one of the four categories:
# 	- Unacceptable Risk: Is the AI system doing something that is explicitly banned (e.g., social scoring, real-time remote biometric identification in public spaces by law enforcement)?
# 	- High-Risk: Could the system have a significant impact on your safety, fundamental rights, or access to essential services? (e.g., AI used in educational scoring, recruitment, or credit scoring). Justify why it falls into a specific high-risk category listed in Annex III of the Act.
# 	- Limited or Minimal Risk: Does the system interact with you in a way that should require transparency? (e.g., chatbots, deepfakes, generative AI).
#
# 4. Justify Your Reasoning: For each classification, write a short paragraph explaining your decision, referencing specific criteria from the AI Act.

# %% [markdown]
# 1.
# - Spotify song recommendations use a variety of algorithms, including some AI.
# - Gmail uses AI to categorize emails into Spam, Junk, Marketing etc.
# - Streaming services (i'd imagine most) use AI for recommending content
# - Image hosting service on my NAS recognizes faces using AI
# - Some genetic data is analyzed with AI at work
# - ChatGPT is fully based on an AI (LLM)
# - Online stores like Verkkokauppa or Amazon likely use AI for recommending products
# - Fraud detection often utilizes AI (technically daily, as I make daily purchases)
# - Siri uses speech recognition and has ChatGPT integration
# - Many translators use some kind of AI (DeepL etc.)
# 2.
# - Spotify has algorithms that gather information about songs, bpm, lyrics, genres etc. This data is fed into a neural network for similarity recognition and finally output to the user. This is a very simplified version of how this works.
# - Gmail uses supervised machine-learning to categorize messages into different categories. Everything from message contents, the sender or the metadata are used by the AI to sort the message into its own category.
# - Siri uses various natural language processing methods such as speech recognition and natural language processing to convert speech into a better format. This data is then used to generate a response, which is passed onto a speech synthesis model. All stages use AI in some way.
# 3.
# - Spotify song recommendations cause little to no risk. It can indirectly affect the user's listening choices, but even this is harmless. Still, it might be worth knowing that the recommendation system does use AI in the background. Limited or Minimal Risk.
# - Email sorting does not make decisions for the user, and the user can affect how it works. Sometimes emails get miscategorized, but no other harm is done. This also falls into the Limited or Minimal Risk category.
# - Siri is the only example where transparency should be enforced, and the user should know they are talking to an AI. Siri does not make choices for you, or limit your access to services etc. Limited or Minimal Risk.
#
# 4.
# All three can utilize these rules:
# - Personalization with transparency -> Limited risk
# - No choices made for the user, full control remains -> Minimal risk
#
# Spotify recommendations can affect the listening habits of its users, but it does not affect fundamental rights or access to essential services etc. Generally speaking AI systems that only recommend content are marked as Limited to Minimal Risk, as long as there is enough transparency and the recommendations aren't harmful. In this case harmful recommendations aren't really possible.
#
# Similar to Spotify, Gmail does not make decisions on the user's behalf. It's supposed to work as an assistant, reducing the need for manual categorization. Everything it does is able to be overridden and the algorithm itself can be adjusted by the user. Once again, with enough transparency there is practically no risk.
#
# Like the other two, there is very little risk in using Siri. As long as the user knows they are communicating with an AI, there is no risk for harm. Siri does not affect access to services or do anything that would categorize it higher than the others.
